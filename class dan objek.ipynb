# %%
#class
class kubus :
    def __init__(self,s) :
        self.sisi= s
        
    def tampilkansisi(self):
        print (self.sisi)
        
    def luas(self) :
        print ("luas", self.sisi**2)
        
    def volume(self) :
        print("volue=", self.sisi**3)
        
    def luas_permukaan(self) :
        print("luas permukaan", self.sisi*6)
    
kubus1=kubus(4)
kubus1.tampilkansisi()
kubus1.luas()
kubus1.volume()
kubus1.luas_permukaan()
# Out:
# 4
# luas 16
# volue= 64
# luas permukaan 4096

# %%
#class
class kubus :
    def __init__(self,s) :
        self.sisi= s
        
    def tampilkansisi(self):
        print (self.sisi)
        
    def luas(self) :
        print ("luas", self.sisi**2)
        
    def volume(self) :
        print("volue=", self.sisi**3)
        
    def luas_permukaan(self) :
        print("luas permukaan", self.sisi*6)
    
kubus1=kubus(4)
kubus1.tampilkansisi()
kubus1.luas()
kubus1.volume()
kubus1.luas_permukaan()
# Out:
# 4
# luas 16
# volue= 64
# luas permukaan 4096

# %%
class mahasiswa :
    def __init__ (self,npm,nm,ipk):
        self.NIM=npm
        self.Nama=nm
        self.IPK=ipk
        
    def tampilkan(self):
        print("NIM :", self.NIM, "Nama :", self.Nama, "IPK :", self.IPK)
        
    def predikator(self):
        if self.IPK  >= 3.5 :
            print ("cumlaude")
        elif self.IPK < 3.5 :
            print ("sangat memuaskan")
        elif self.IPK <= 3.5 :
            print ("cukup")

mhs1=mahasiswa("170411100087", "Ana Maghfiroh",4.0)
mhs1.tampilkan()
mhs1.predikator()
# Out:
# NIM : 170411100087 Nama : Ana Maghfiroh IPK : 4.0
# cumlaude

# %%
class nasabah :
    def __init__ (self,no,nm,rek) :
        self.NomerNasabah=no
        self.NamaNasabah=nm
        self.NomerRek=rek
    
    def tampilkan(self):
        print("N0.Nasabah :", self.NomerNasabah, "Nama Nasabah :", self.NamaNasabah, "Nomer Rekening :", self.NomerRek)
        
class rekening():
    def __init__ (self,rek,sal):
        self.rekening=rek
        self.saldo=sal
    def ambil(self) :
        ambil_uang=int(input("ambil uang dengan senilai :"))
        hasil=self.saldo-ambil_uang
        self.saldo = hasil
        print ("jumlah penarikan :", ambil_uang, "sisa :", hasil)
    def setor(self):
        setor_uang=int(input("menyetorkan uang dengan senilai :"))
        hasil=self.saldo+setor_uang
        self.saldo = hasil
        print ("jumlah setoran :", setor_uang, "sisa :", hasil)
    def cek_saldo(self):
        print ("saldo", self.saldo)
    
fera=nasabah("1", "Ana Maghfiroh", "170411100087")
fera.tampilkan()

fera_rek=rekening("170411100087",1000000)
fera_rek.ambil()
fera_rek.setor()
fera_rek.cek_saldo()
# Out:
# N0.Nasabah : 1 Nama Nasabah : Ana Maghfiroh Nomer Rekening : 170411100087
# ambil uang dengan senilai :5000
# jumlah penarikan : 5000 sisa : 995000
# menyetorkan uang dengan senilai :5000
# jumlah setoran : 5000 sisa : 1000000
# saldo 1000000

# %%
import datetime
now = datetime.datetime.now()

class pegawai :
    def __init__ (self,No,nm,tgllahir) :
        self.Nomer=No
        self.Nama_Pegawai=nm
        self.Tanggal_Lahir=tgllahir
    
    def tampilkan(self):
        lahir = self.Tanggal_Lahir
        tahunLahir = int(lahir[-4:])
        tahunSekarang = now.year
        umur = tahunSekarang - tahunLahir
        print("No. Pegawai :", self.Nomer, "Nama Pegawai :", self.Nama_Pegawai, "Umur :", umur)
        
        

fera=pegawai("170411100087", "Ana Maghfiroh", "12 maret 1999")
fera.tampilkan()
fera.umur()
# Out:
# No. Pegawai : 170411100087 Nama Pegawai : Ana Maghfiroh Umur : 19
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-4643a6a14b04> in <module>()
#      19 fera=pegawai("170411100087", "Ana Maghfiroh", "12 maret 1999")
#      20 fera.tampilkan()
# ---> 21 fera.umur()
#
# AttributeError: 'pegawai' object has no attribute 'umur'

# %% [markdown]
# objek : sekumpulan software yang terdiri dari variable dan method-method yang terkait. Objek juga merupakan benda nyata yang di buat berdasarkan rancangan yang di definisikan di dalam class
#
# Object adalah instance dari class. Jika class secara umum mepresentasikan (template) sebuah object, sebuah instance adalah representasi nyata dari class itu sendiri. Contoh : Dari class Fruit kita dapat membuat object Mangga, Pisang, Apel, dan lain-lain.
#
# class : Class adalah prototype, atau blueprint, atau rancangan yang mendefinisikan variable dan method-methode pada seluruh objek tertentu. Class berfungsi untuk menampung isi dari program yang akan di jalankan, di dalamnya berisi atribut / type data dan method untuk menjalankan suatu program.
#
#
# method : Method adalah kumpulan program yang mempunyai nama. Method merupakan sarana bagi programmer untuk memecah program menjadi bagian-bagian yang kecil agar jadi lebih kompleks sehingga dapat di gunakan berulang-ulang.

# %%
def waktu():
    import time
    a=time.localtime()
    hr=a.tm_hour
    mn=a.tm_min
    sc=a.tm_sec
    return ('{}:{}:{}'.format(hr,mn,sc))
waktu()

def ucapan():
    nama = input("Masukkan Nama: ")
    a=waktu()
    if a > "00:00:00" and a < "10:00:00":
        print("Selamat Pagi", nama)
    elif a > "10:00:00" and a < "15:00:00":
        print("Selamat siang", nama)
    elif a > "15:00:00" and a < "18:00:00":
        print("Selamat Sore", nama)
    else :
        print ("Selamat Malem", nama)
ucapan()

# %%
a = 3
b = 7
c = 2
for i in range(a,b+1):
    for j in range(c):
        print (a,end="")
    a+=1
    print ()

#No. 2B
a = 8
b = 10
c = 4
for i in range(a,b+1):
    for j in range(c):
        print (a,end="")
    a+=1
    print ()

#3
#No. 3A dan 3B
for i in range(2):
    a = int(input("a : "))
    b = int(input("b : "))
    for i in range(a, b+1, 2):
        #for j in range (a):
        print(i)
#No. 3C
a = int(input("a : "))
b = int(input("b : "))
for i in range(a+1, b, 2):
    #for j in range (a):
    print(i)

# %%
class user :
    def __init__(self,name):
        self.name=name
    def printname(self):
        print("First Name =" + self.name)

class programmer(user):
    def __init__(self,lastname):
        self.lastname=lastname
    def printname(self):
        print("First Name =" + user.name)
    def printlastname(self):
        print("Last Name =" + self.lastname)
    def tampilkan(self):
        print("full name="+ user.name + self.lastname)
    def dopython(self):
        print("i am programming python")
        
class programmer1(user):
    pass

user=user("Ana Maghfiroh")
user.printname()

programmer=programmer("Fitri ")
programmer.printname()
programmer.printlastname()
programmer.tampilkan( )
programmer.dopython()

user1=programmer1("Ana Maghfiroh")
user1.printname()
print()
        
#No. 2

import time
class orang:
    def __init__(self,nama):
        self.nama=nama
    def printNama(self):
        print ('nama: ',self.nama)
        
class mahasiswa(orang):
    def __init__(self,nim,nama):
        super().__init__(nama)
        self.nim=nim
        self.smester=0
    def smester(self):
        tahun=time.strftime("%Y");bulan=int(time.strftime("%m"))
        masuk=int(self.nim[0:2])
        if int(bulan)>=8:
            self.smester=(int(tahun[2:4])-int(masuk))*2+1
        else:
            self.smester=(int(tahun[2:4])-int(masuk))*2
    def display_mhs(self):
        mahasiswa.smester(self)
        print ('nama :',self.nama,'nim :',self.nim, 'smester :',self.smester)
        
class pegawai(orang):
    def __init__(self,nip,nama):
        super().__init__(nama)
        self.nip=nip
    def display_pegawai(self):
        print ('nama :',self.nama,'nip :',self.nip)
class dosen(pegawai):
    def __init__(self,nama,nip,nidn):
        super().__init__(nip,nama)
        self.nidn=nidn
    def display_dosen(self):
        print ('nama :',self.nama,'nip :',self.nip,'nidn :',self.nidn)
class karyawan(pegawai):
    pass
        

x=orang('xxx')
x.printNama()
mhs=mahasiswa('170411100087','Ana Maghfiroh')
mhs.printNama()
mhs.display_mhs()
print ()

Dosen=dosen('Fitri','199 0 1 00000 97','45678')
Dosen.display_dosen()
print ()

Karyawan=karyawan('9588884','Zulha')
Karyawan.display_pegawai()
